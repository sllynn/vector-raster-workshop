# %%
# %pip install earthaccess

# %%
# %sql
CREATE VOLUME IF NOT EXISTS stuart.lv.geotiffs;

# %%
catalog = "stuart"
schema = "lv"
volume = "geotiffs"

# %%
import os

import earthaccess

# %% [markdown]
# + Register [here](https://urs.earthdata.nasa.gov/users/new)
# + Set-up secrets to hold credentials by following the instructions [here](https://learn.microsoft.com/en-us/azure/databricks/security/secrets/#create-a-databricks-backed-secret-scope)

# %%
os.environ["EARTHDATA_USERNAME"] = dbutils.secrets.get(scope = "stuart", key = "earthdata-login")
os.environ["EARTHDATA_PASSWORD"] = dbutils.secrets.get(scope = "stuart", key = "earthdata-password")

# %%
auth = earthaccess.login(strategy="environment")

# %%
results = earthaccess.search_data(
    short_name='HLSL30_VI',
    bounding_box=(17.05,46.45,18.35,47.30),
    temporal=("2025-06-01", "2025-06-30"),
    count=10
)

# %%
earthaccess.download(results, f"/Volumes/{catalog}/{schema}/{volume}")
